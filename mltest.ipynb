# %% [markdown]
# ### This model model will accept X and Y coordinates
# When we submit a new X value, the model will precict the probably of the Y value

# %%
print( "Hello World" )
# Out:
# Hello World

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ### 🛠️ Model preparedness
# 1. Create a model
# 2. Define the training dataset
# 3. Create the model

# %%
# Create a model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# Define X and Y training data
xs = np.array( [ -1.0, 0.0, 1.0, 2.0,  3.0,  4.0 ], dtype = float )
ys = np.array( [ -2.0, 1.0, 4.0, 7.0, 10.0, 13.0 ], dtype = float )

# Define the model
model.fit( xs, ys, epochs = 400 )
# Out:
# Epoch 1/400
# 1/1 [==============================] - 0s 465ms/step - loss: 15.3044
# Epoch 2/400
# 1/1 [==============================] - 0s 11ms/step - loss: 12.0679
# Epoch 3/400
# 1/1 [==============================] - 0s 18ms/step - loss: 9.5210
# Epoch 4/400
# 1/1 [==============================] - 0s 16ms/step - loss: 7.5167
# Epoch 5/400
# 1/1 [==============================] - 0s 26ms/step - loss: 5.9393
# Epoch 6/400
# 1/1 [==============================] - 0s 28ms/step - loss: 4.6977
# Epoch 7/400
# 1/1 [==============================] - 0s 18ms/step - loss: 3.7204
# Epoch 8/400
# 1/1 [==============================] - 0s 19ms/step - loss: 2.9510
# Epoch 9/400
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3452
# Epoch 10/400
# 1/1 [==============================] - 0s 17ms/step - loss: 1.8681
# Epoch 11/400
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4922
# Epoch 12/400
# ...

# %% [markdown]
# ## 🚀 Model prediction

# %%
# Use the model to predict the 
# value of Y based on an X input ( 5 )
prediction = model.predict( [ 5.0 ] )
print( "Prediction: ", prediction ) # 16.0
# Out:
# 1/1 [==============================] - 0s 103ms/step
# Prediction:  [[16.004797]]
